# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !pip install tensorboardcolab
# Out:
# Collecting tensorboardcolab
#   Downloading https://files.pythonhosted.org/packages/8a/06/136329883f8ceae71b46c874840fd45aab86116bfa0cd61d0fc10cf3c52e/tensorboardcolab-0.0.20.tar.gz
# Building wheels for collected packages: tensorboardcolab
# done
#   Stored in directory: /root/.cache/pip/wheels/33/cf/fe/750a8f7de59b74b0f40497c9c778ef06a968f319f0a3e85361
# Successfully built tensorboardcolab
# Installing collected packages: tensorboardcolab
# Successfully installed tensorboardcolab-0.0.20

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/AI/')

# %%
from tensorboardcolab import *
tbc=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# http://fb136361.ngrok.io

# %%
import cv2
import sys
import numpy as np
import tensorflow as tf

# sess = tf.Session()
# sess.run(tf.global_variables_initializer())
tf.global_variables_initializer()

def parser(record):
    keys_to_features = {
        "image_raw": tf.FixedLenFeature([], tf.string),
        "label":     tf.FixedLenFeature([], tf.int64)
    }
    parsed = tf.parse_single_example(record, keys_to_features)
    image = tf.decode_raw(parsed["image_raw"], tf.uint8)
    image = tf.cast(image, tf.float32)
    label = tf.cast(parsed["label"], tf.int32)

    return {'image': image}, label

def input_fn(filenames):
  dataset = tf.data.TFRecordDataset(filenames=filenames, num_parallel_reads=40)
  dataset = dataset.apply(
      tf.data.experimental.shuffle_and_repeat(300, 1)
  )
  dataset = dataset.apply(
      tf.data.experimental.map_and_batch(parser, 100)
  )
  dataset = dataset.prefetch(buffer_size=2)
  return dataset


def train_input_fn():
    return input_fn(filenames=["train.tfrecords", "test.tfrecords"])

def val_input_fn():
    return input_fn(filenames=["val.tfrecords"])

def model_fn(features, labels, mode, params):
    num_classes = 2
    net = features["image"]

    net = tf.identity(net, name="input_tensor")
    
    net = tf.reshape(net, [-1, 224, 224, 1])    

    net = tf.identity(net, name="input_tensor_after")

    net = tf.layers.conv2d(inputs=net, name='layer_conv1',
                           filters=64, kernel_size=2,
                           padding='SAME', activation=tf.nn.relu)  
    net = tf.layers.max_pooling2d(inputs=net, pool_size=2, strides=2)

    net = tf.layers.conv2d(inputs=net, name='layer_conv2',
                           filters=64, kernel_size=2,
                           padding='SAME', activation=tf.nn.relu)
    net = tf.layers.max_pooling2d(inputs=net, pool_size=2, strides=2)

    net = tf.layers.conv2d(inputs=net, name='layer_conv3',
                           filters=64, kernel_size=2,
                           padding='same', activation=tf.nn.relu)
    net = tf.layers.max_pooling2d(inputs=net, pool_size=2, strides=2)
    
    net = tf.layers.conv2d(inputs=net, name='layer_conv4',
                       filters=128, kernel_size=2,
                       padding='same', activation=tf.nn.relu)
    net = tf.layers.max_pooling2d(inputs=net, pool_size=2, strides=2)
    
#     net = tf.layers.conv2d(inputs=net, name='layer_conv5',
#                        filters=128, kernel_size=,
#                        padding='same', activation=tf.nn.relu)  
#     net = tf.layers.max_pooling2d(inputs=net, pool_size=2, strides=2)    

    net = tf.contrib.layers.flatten(net)
    
#     net = tf.layers.dense(inputs=net, name='layer_fc1',
#                         units=1024, activation=tf.nn.relu)
    
    net = tf.layers.dense(inputs=net, name='layer_fc2',
                    units=128, activation=tf.nn.relu)
    
#     net = tf.layers.dropout(net, rate=0.4, noise_shape=None, 
#                         seed=None, training=(mode == tf.estimator.ModeKeys.TRAIN))
    
    net = tf.layers.dense(inputs=net, name='layer_fc3',
                    units=128, activation=tf.nn.relu)
    
    net = tf.layers.dense(inputs=net, name='layer_fc_4',
                        units=num_classes)

    logits = net
    y_pred = tf.nn.softmax(logits=logits)

    y_pred = tf.identity(y_pred, name="output_pred")

    y_pred_cls = tf.argmax(y_pred, axis=1)

    y_pred_cls = tf.identity(y_pred_cls, name="output_cls")

    if mode == tf.estimator.ModeKeys.PREDICT:
        spec = tf.estimator.EstimatorSpec(mode=mode,
                                          predictions=y_pred_cls)
    else:
        cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels,
                                                                       logits=logits)
        loss = tf.reduce_mean(cross_entropy)

        optimizer = tf.train.AdamOptimizer(learning_rate=params["learning_rate"])
        
        train_op = optimizer.minimize(
            loss=loss, global_step=tf.train.get_global_step())

        metrics = {
            "accuracy": tf.metrics.accuracy(labels, y_pred_cls)
        }

        spec = tf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss,
            train_op=train_op,
            eval_metric_ops=metrics,
        )
        
    return spec

# %%
model = tf.estimator.Estimator(model_fn=model_fn,
                               params={"learning_rate": 0.000009},
                               model_dir="/content/drive/My Drive/AI/spider_model25/")

epoch = 0
avg = 0
while (epoch < 1000):
    model.train(input_fn=train_input_fn, steps=100)
    result = model.evaluate(input_fn=val_input_fn)
    
    tbc.save_value("Accuracy/Epoch", "gf1", epoch, result["accuracy"]*100)
    tbc.save_value("Loss/Epoch", "gf2", epoch, result["loss"])
    
    
    tbc.flush_line("gf1")
    tbc.flush_line("gf2")
    tbc.close()

    sys.stdout.flush()
    epoch = epoch + 1
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/content/drive/My Drive/AI/spider_model25/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff4b6782a58>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 7.1287236, step = 0
# INFO:tensorflow:Saving checkpoints for 15 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.2616713.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-16:59:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-15
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-16:59:25
# INFO:tensorflow:Saving dict for global step 15: accuracy = 0.58113205, global_step = 15, loss = 1.3223281
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15: /content/drive/My Drive/AI/spider_model25/model.ckpt-15
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-15
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 15 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 1.0118071, step = 15
# INFO:tensorflow:Saving checkpoints for 30 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.92998606.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-16:59:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-16:59:35
# INFO:tensorflow:Saving dict for global step 30: accuracy = 0.5169811, global_step = 30, loss = 0.9233572
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 30: /content/drive/My Drive/AI/spider_model25/model.ckpt-30
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 30 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.9643859, step = 30
# INFO:tensorflow:Saving checkpoints for 45 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.8197518.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-16:59:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-45
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-16:59:45
# INFO:tensorflow:Saving dict for global step 45: accuracy = 0.61132073, global_step = 45, loss = 0.8068185
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45: /content/drive/My Drive/AI/spider_model25/model.ckpt-45
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-45
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 45 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.6811099, step = 45
# INFO:tensorflow:Saving checkpoints for 60 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.78812563.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-16:59:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-16:59:55
# INFO:tensorflow:Saving dict for global step 60: accuracy = 0.56981134, global_step = 60, loss = 0.7755632
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 60: /content/drive/My Drive/AI/spider_model25/model.ckpt-60
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 60 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.72338724, step = 60
# INFO:tensorflow:Saving checkpoints for 75 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.8141078.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:00:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-75
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:00:05
# INFO:tensorflow:Saving dict for global step 75: accuracy = 0.56981134, global_step = 75, loss = 0.8019262
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 75: /content/drive/My Drive/AI/spider_model25/model.ckpt-75
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-75
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 75 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.9286818, step = 75
# INFO:tensorflow:Saving checkpoints for 90 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.712092.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:00:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:00:15
# INFO:tensorflow:Saving dict for global step 90: accuracy = 0.61509436, global_step = 90, loss = 0.76929635
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 90: /content/drive/My Drive/AI/spider_model25/model.ckpt-90
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 90 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.60347295, step = 90
# INFO:tensorflow:Saving checkpoints for 105 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.6176519.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:00:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-105
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:00:26
# INFO:tensorflow:Saving dict for global step 105: accuracy = 0.6037736, global_step = 105, loss = 0.7569857
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 105: /content/drive/My Drive/AI/spider_model25/model.ckpt-105
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-105
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 105 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.63695246, step = 105
# INFO:tensorflow:Saving checkpoints for 120 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.7259266.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:00:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:00:36
# INFO:tensorflow:Saving dict for global step 120: accuracy = 0.6226415, global_step = 120, loss = 0.71222115
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 120: /content/drive/My Drive/AI/spider_model25/model.ckpt-120
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 120 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.564316, step = 120
# INFO:tensorflow:Saving checkpoints for 135 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.8573643.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:00:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-135
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:00:46
# INFO:tensorflow:Saving dict for global step 135: accuracy = 0.61509436, global_step = 135, loss = 0.7367563
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 135: /content/drive/My Drive/AI/spider_model25/model.ckpt-135
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-135
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 135 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.57278967, step = 135
# INFO:tensorflow:Saving checkpoints for 150 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.72358304.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:00:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:00:56
# INFO:tensorflow:Saving dict for global step 150: accuracy = 0.61886793, global_step = 150, loss = 0.78653854
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 150: /content/drive/My Drive/AI/spider_model25/model.ckpt-150
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 150 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.5549729, step = 150
# INFO:tensorflow:Saving checkpoints for 165 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.6078965.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:01:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-165
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:01:06
# INFO:tensorflow:Saving dict for global step 165: accuracy = 0.61886793, global_step = 165, loss = 0.7133216
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 165: /content/drive/My Drive/AI/spider_model25/model.ckpt-165
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-165
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 165 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.6202805, step = 165
# INFO:tensorflow:Saving checkpoints for 180 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.60727686.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:01:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-180
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:01:17
# INFO:tensorflow:Saving dict for global step 180: accuracy = 0.6301887, global_step = 180, loss = 0.7447303
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 180: /content/drive/My Drive/AI/spider_model25/model.ckpt-180
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-180
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 180 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.6666008, step = 180
# INFO:tensorflow:Saving checkpoints for 195 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5765825.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:01:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-195
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:01:27
# INFO:tensorflow:Saving dict for global step 195: accuracy = 0.61132073, global_step = 195, loss = 0.7050751
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 195: /content/drive/My Drive/AI/spider_model25/model.ckpt-195
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-195
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 195 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.55753136, step = 195
# INFO:tensorflow:Saving checkpoints for 210 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4660818.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:01:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-210
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:01:37
# INFO:tensorflow:Saving dict for global step 210: accuracy = 0.6528302, global_step = 210, loss = 0.67895085
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 210: /content/drive/My Drive/AI/spider_model25/model.ckpt-210
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-210
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 210 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.526696, step = 210
# INFO:tensorflow:Saving checkpoints for 225 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5650462.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:01:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-225
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:01:47
# INFO:tensorflow:Saving dict for global step 225: accuracy = 0.6301887, global_step = 225, loss = 0.6941517
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 225: /content/drive/My Drive/AI/spider_model25/model.ckpt-225
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-225
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 225 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.63790625, step = 225
# INFO:tensorflow:Saving checkpoints for 240 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.43493837.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:01:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-240
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:01:58
# INFO:tensorflow:Saving dict for global step 240: accuracy = 0.61509436, global_step = 240, loss = 0.6779365
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 240: /content/drive/My Drive/AI/spider_model25/model.ckpt-240
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-240
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 240 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.4717808, step = 240
# INFO:tensorflow:Saving checkpoints for 255 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.48361552.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:02:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-255
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:02:08
# INFO:tensorflow:Saving dict for global step 255: accuracy = 0.6792453, global_step = 255, loss = 0.68826014
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 255: /content/drive/My Drive/AI/spider_model25/model.ckpt-255
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-255
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 255 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.46871254, step = 255
# INFO:tensorflow:Saving checkpoints for 270 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.52914256.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:02:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-270
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:02:18
# INFO:tensorflow:Saving dict for global step 270: accuracy = 0.61509436, global_step = 270, loss = 0.7683489
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 270: /content/drive/My Drive/AI/spider_model25/model.ckpt-270
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-270
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 270 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.54605824, step = 270
# INFO:tensorflow:Saving checkpoints for 285 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.51678544.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:02:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-285
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:02:28
# INFO:tensorflow:Saving dict for global step 285: accuracy = 0.6226415, global_step = 285, loss = 0.7042799
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 285: /content/drive/My Drive/AI/spider_model25/model.ckpt-285
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-285
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 285 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.56299514, step = 285
# INFO:tensorflow:Saving checkpoints for 300 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.59114933.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:02:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:02:38
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.65660375, global_step = 300, loss = 0.66178256
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 300: /content/drive/My Drive/AI/spider_model25/model.ckpt-300
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 300 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.470593, step = 300
# INFO:tensorflow:Saving checkpoints for 315 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.44078928.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:02:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-315
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:02:48
# INFO:tensorflow:Saving dict for global step 315: accuracy = 0.63773584, global_step = 315, loss = 0.6999757
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 315: /content/drive/My Drive/AI/spider_model25/model.ckpt-315
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-315
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 315 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.5501948, step = 315
# INFO:tensorflow:Saving checkpoints for 330 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5530164.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:02:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-330
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:02:59
# INFO:tensorflow:Saving dict for global step 330: accuracy = 0.61509436, global_step = 330, loss = 0.7221597
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 330: /content/drive/My Drive/AI/spider_model25/model.ckpt-330
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-330
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 330 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.5823978, step = 330
# INFO:tensorflow:Saving checkpoints for 345 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.49162218.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:03:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-345
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:03:09
# INFO:tensorflow:Saving dict for global step 345: accuracy = 0.6301887, global_step = 345, loss = 0.7028453
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 345: /content/drive/My Drive/AI/spider_model25/model.ckpt-345
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-345
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 345 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.51315224, step = 345
# INFO:tensorflow:Saving checkpoints for 360 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.42133433.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:03:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:03:19
# INFO:tensorflow:Saving dict for global step 360: accuracy = 0.6415094, global_step = 360, loss = 0.6904469
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 360: /content/drive/My Drive/AI/spider_model25/model.ckpt-360
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 360 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.5199931, step = 360
# INFO:tensorflow:Saving checkpoints for 375 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.43966386.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:03:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:03:29
# INFO:tensorflow:Saving dict for global step 375: accuracy = 0.69056606, global_step = 375, loss = 0.6304554
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 375: /content/drive/My Drive/AI/spider_model25/model.ckpt-375
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 375 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.34634495, step = 375
# INFO:tensorflow:Saving checkpoints for 390 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.38560376.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:03:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-390
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:03:40
# INFO:tensorflow:Saving dict for global step 390: accuracy = 0.6490566, global_step = 390, loss = 0.6754163
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 390: /content/drive/My Drive/AI/spider_model25/model.ckpt-390
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-390
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 390 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.4720012, step = 390
# INFO:tensorflow:Saving checkpoints for 405 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.42497447.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:03:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-405
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:03:50
# INFO:tensorflow:Saving dict for global step 405: accuracy = 0.6981132, global_step = 405, loss = 0.6371046
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 405: /content/drive/My Drive/AI/spider_model25/model.ckpt-405
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-405
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 405 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.31253082, step = 405
# INFO:tensorflow:Saving checkpoints for 420 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.38562724.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:03:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-420
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:04:00
# INFO:tensorflow:Saving dict for global step 420: accuracy = 0.68301886, global_step = 420, loss = 0.65644896
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 420: /content/drive/My Drive/AI/spider_model25/model.ckpt-420
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-420
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 420 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.36119893, step = 420
# INFO:tensorflow:Saving checkpoints for 435 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.42863068.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:04:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-435
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:04:11
# INFO:tensorflow:Saving dict for global step 435: accuracy = 0.6603774, global_step = 435, loss = 0.65691215
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 435: /content/drive/My Drive/AI/spider_model25/model.ckpt-435
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-435
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 435 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.50016916, step = 435
# INFO:tensorflow:Saving checkpoints for 450 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.34833542.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:04:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:04:21
# INFO:tensorflow:Saving dict for global step 450: accuracy = 0.7018868, global_step = 450, loss = 0.624665
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 450: /content/drive/My Drive/AI/spider_model25/model.ckpt-450
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 450 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.31159106, step = 450
# INFO:tensorflow:Saving checkpoints for 465 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4504423.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:04:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-465
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:04:31
# INFO:tensorflow:Saving dict for global step 465: accuracy = 0.69433963, global_step = 465, loss = 0.62093234
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 465: /content/drive/My Drive/AI/spider_model25/model.ckpt-465
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-465
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 465 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.3900002, step = 465
# INFO:tensorflow:Saving checkpoints for 480 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.38573316.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:04:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-480
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:04:41
# INFO:tensorflow:Saving dict for global step 480: accuracy = 0.7018868, global_step = 480, loss = 0.62761796
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 480: /content/drive/My Drive/AI/spider_model25/model.ckpt-480
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-480
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 480 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.34857133, step = 480
# INFO:tensorflow:Saving checkpoints for 495 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3804722.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:04:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-495
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:04:52
# INFO:tensorflow:Saving dict for global step 495: accuracy = 0.7018868, global_step = 495, loss = 0.631785
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 495: /content/drive/My Drive/AI/spider_model25/model.ckpt-495
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-495
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 495 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.35514194, step = 495
# INFO:tensorflow:Saving checkpoints for 510 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3160475.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:05:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-510
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:05:02
# INFO:tensorflow:Saving dict for global step 510: accuracy = 0.7056604, global_step = 510, loss = 0.6340615
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 510: /content/drive/My Drive/AI/spider_model25/model.ckpt-510
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-510
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 510 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.2808061, step = 510
# INFO:tensorflow:Saving checkpoints for 525 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3570415.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:05:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-525
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:05:12
# INFO:tensorflow:Saving dict for global step 525: accuracy = 0.71320754, global_step = 525, loss = 0.63015574
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 525: /content/drive/My Drive/AI/spider_model25/model.ckpt-525
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-525
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 525 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.28104356, step = 525
# INFO:tensorflow:Saving checkpoints for 540 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.39778396.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:05:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-540
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:05:23
# INFO:tensorflow:Saving dict for global step 540: accuracy = 0.6792453, global_step = 540, loss = 0.63596576
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 540: /content/drive/My Drive/AI/spider_model25/model.ckpt-540
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-540
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 540 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.39448467, step = 540
# INFO:tensorflow:Saving checkpoints for 555 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.29545215.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:05:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-555
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:05:33
# INFO:tensorflow:Saving dict for global step 555: accuracy = 0.6754717, global_step = 555, loss = 0.66157836
# ...
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 855: /content/drive/My Drive/AI/spider_model25/model.ckpt-855
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-855
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 855 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.18836151, step = 855
# INFO:tensorflow:Saving checkpoints for 870 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.22369958.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:09:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-870
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:09:10
# INFO:tensorflow:Saving dict for global step 870: accuracy = 0.72075474, global_step = 870, loss = 0.6416087
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 870: /content/drive/My Drive/AI/spider_model25/model.ckpt-870
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-870
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 870 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.20696598, step = 870
# INFO:tensorflow:Saving checkpoints for 885 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.20277438.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:09:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-885
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:09:20
# INFO:tensorflow:Saving dict for global step 885: accuracy = 0.7283019, global_step = 885, loss = 0.6207996
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 885: /content/drive/My Drive/AI/spider_model25/model.ckpt-885
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-885
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 885 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.21468788, step = 885
# INFO:tensorflow:Saving checkpoints for 900 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.21412246.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:09:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:09:30
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.73207545, global_step = 900, loss = 0.64284545
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 900: /content/drive/My Drive/AI/spider_model25/model.ckpt-900
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 900 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.2102418, step = 900
# INFO:tensorflow:Saving checkpoints for 915 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.21385686.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:09:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-915
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:09:41
# INFO:tensorflow:Saving dict for global step 915: accuracy = 0.7358491, global_step = 915, loss = 0.6325558
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 915: /content/drive/My Drive/AI/spider_model25/model.ckpt-915
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-915
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 915 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.21164861, step = 915
# INFO:tensorflow:Saving checkpoints for 930 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.22568665.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:09:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-930
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:09:51
# INFO:tensorflow:Saving dict for global step 930: accuracy = 0.7283019, global_step = 930, loss = 0.6738736
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 930: /content/drive/My Drive/AI/spider_model25/model.ckpt-930
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-930
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 930 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.24136925, step = 930
# INFO:tensorflow:Saving checkpoints for 945 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.23398319.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:10:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-945
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:10:02
# INFO:tensorflow:Saving dict for global step 945: accuracy = 0.7358491, global_step = 945, loss = 0.6517799
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 945: /content/drive/My Drive/AI/spider_model25/model.ckpt-945
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-945
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 945 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.21916118, step = 945
# INFO:tensorflow:Saving checkpoints for 960 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.1696521.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:10:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-960
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:10:12
# INFO:tensorflow:Saving dict for global step 960: accuracy = 0.71320754, global_step = 960, loss = 0.66847926
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 960: /content/drive/My Drive/AI/spider_model25/model.ckpt-960
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-960
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 960 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.22547437, step = 960
# INFO:tensorflow:Saving checkpoints for 975 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.1565844.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:10:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-975
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:10:22
# INFO:tensorflow:Saving dict for global step 975: accuracy = 0.7056604, global_step = 975, loss = 0.6378257
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 975: /content/drive/My Drive/AI/spider_model25/model.ckpt-975
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-975
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 975 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.2003182, step = 975
# INFO:tensorflow:Saving checkpoints for 990 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14137757.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:10:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-990
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:10:33
# INFO:tensorflow:Saving dict for global step 990: accuracy = 0.7358491, global_step = 990, loss = 0.6471965
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 990: /content/drive/My Drive/AI/spider_model25/model.ckpt-990
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-990
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 990 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.1827061, step = 990
# INFO:tensorflow:Saving checkpoints for 1005 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.18127647.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:10:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-1005
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:10:43
# INFO:tensorflow:Saving dict for global step 1005: accuracy = 0.72075474, global_step = 1005, loss = 0.6126332
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1005: /content/drive/My Drive/AI/spider_model25/model.ckpt-1005
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-1005
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1005 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.146867, step = 1005
# INFO:tensorflow:Saving checkpoints for 1020 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14286208.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:10:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-1020
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:10:53
# INFO:tensorflow:Saving dict for global step 1020: accuracy = 0.71320754, global_step = 1020, loss = 0.6464049
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1020: /content/drive/My Drive/AI/spider_model25/model.ckpt-1020
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-1020
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1020 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.15661548, step = 1020
# INFO:tensorflow:Saving checkpoints for 1035 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.15255465.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-11-17:11:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-1035
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-11-17:11:04
# INFO:tensorflow:Saving dict for global step 1035: accuracy = 0.73207545, global_step = 1035, loss = 0.60866135
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1035: /content/drive/My Drive/AI/spider_model25/model.ckpt-1035
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/AI/spider_model25/model.ckpt-1035
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1035 into /content/drive/My Drive/AI/spider_model25/model.ckpt.
# INFO:tensorflow:loss = 0.15382299, step = 1035

# %%
from random import shuffle
import glob
import sys
import cv2
import numpy as np
import tensorflow as tf

def _int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))
    
def _bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def load_image(addr):
    img = cv2.imread(addr)
    if img is None:
        return None
    img = cv2.resize(img, (224, 224), interpolation=cv2.INTER_CUBIC)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return img
 
def createDataRecord(out_filename, addrs, labels):
    # open the TFRecords file
    writer = tf.python_io.TFRecordWriter(out_filename)
    for i in range(len(addrs)):
        # print how many images are saved every 1000 images
        if not i % 50:
            print('Train data: {}/{}'.format(i, len(addrs)))
            sys.stdout.flush()

        # Load the image
        img = load_image(addrs[i])
        label = labels[i]

        #  just sentinel to prevent crash
        if img is None:
            continue

        # Create a feature
        feature = {
            'image_raw': _bytes_feature(img.tostring()),
            'label': _int64_feature(label)
        }
        # Create an example protocol buffer
        example = tf.train.Example(features=tf.train.Features(feature=feature))
        
        # Serialize to string and write on the file
        writer.write(example.SerializeToString())
        
    writer.close()
    sys.stdout.flush()

dataset_path = '/content/drive/My Drive/AI/dataset/*/*'
# dataset_path = '/home/peterson/Documents/School/Fall 2018/ML/Project/dataset/*/*'
# read addresses and labels from the 'train' folder
addrs = glob.glob(dataset_path)

labels = [1 if 'spiders' in addr else 0 for addr in addrs]

# to shuffle data
c = list(zip(addrs, labels))
shuffle(c)
addrs, labels = zip(*c)
    
# Divide the data into 60% train, 20% validation, and 20% test
train_addrs = addrs[0:int(0.65*len(addrs))]
train_labels = labels[0:int(0.65*len(labels))]
val_addrs = addrs[int(0.65*len(addrs)):int(0.8*len(addrs))]
val_labels = labels[int(0.65*len(addrs)):int(0.8*len(addrs))]
test_addrs = addrs[int(0.8*len(addrs)):]
test_labels = labels[int(0.8*len(labels)):]

createDataRecord('train.tfrecords', train_addrs, train_labels)
createDataRecord('val.tfrecords', val_addrs, val_labels)
createDataRecord('test.tfrecords', test_addrs, test_labels)
# Out:
# Train data: 0/1147
# Train data: 50/1147
# Train data: 100/1147
# Train data: 150/1147
# Train data: 200/1147
# Train data: 250/1147
# Train data: 300/1147
# Train data: 350/1147
# Train data: 400/1147
# Train data: 450/1147
# Train data: 500/1147
# Train data: 550/1147
# Train data: 600/1147
# Train data: 650/1147
# Train data: 700/1147
# Train data: 750/1147
# Train data: 800/1147
# Train data: 850/1147
# Train data: 900/1147
# Train data: 950/1147
# Train data: 1000/1147
# Train data: 1050/1147
# Train data: 1100/1147
# Train data: 0/265
# Train data: 50/265
# Train data: 100/265
# Train data: 150/265
# Train data: 200/265
# Train data: 250/265
# Train data: 0/354
# Train data: 50/354
# Train data: 100/354
# Train data: 150/354
# Train data: 200/354
# Train data: 250/354
# Train data: 300/354
# Train data: 350/354
